# %%
import pandas as pd
import dask.dataframe as dd
import numpy as np
import collections
import numba
from transformers import pipeline
import spacy

# %%
df = pd.read_csv('C:/Users/abdul/text-mining/Project/mpst_full_data.csv')

# %%
df
# Out:
#          imdb_id                                          title  \
# 0      tt0057603                        I tre volti della paura
# 1      tt1733125  Dungeons & Dragons: The Book of Vile Darkness
# 2      tt0033045                     The Shop Around the Corner
# 3      tt0113862                             Mr. Holland's Opus
# 4      tt0086250                                       Scarface
# ...          ...                                            ...
# 14823  tt0219952                                  Lucky Numbers
# 14824  tt1371159                                     Iron Man 2
# 14825  tt0063443                                     Play Dirty
# 14826  tt0039464                                      High Wall
# 14827  tt0235166                               Against All Hope
#
#                                            plot_synopsis  \
# 0      Note: this synopsis is for the orginal Italian...
# 1      Two thousand years ago, Nhagruul the Foul, a s...
# 2      Matuschek's, a gift store in Budapest, is the ...
# 3      Glenn Holland, not a morning person by anyone'...
# 4      In May 1980, a Cuban man named Tony Montana (A...
# ...                                                  ...
# 14823  In 1988 Russ Richards (John Travolta), the wea...
# 14824  In Russia, the media covers Tony Stark's discl...
# 14825  During the North African Campaign in World War...
# 14826  Steven Kenet catches his unfaithful wife in th...
# 14827  Sometime in the 1950s in Chicago a man, Cecil ...
#
#                                                     tags  split  \
# 0              cult, horror, gothic, murder, atmospheric  train
# 1                                               violence  train
# 2                                               romantic   test
# 3                 inspiring, romantic, stupid, feel-good  train
# 4      cruelty, murder, dramatic, cult, violence, atm...    val
# ...                                                  ...    ...
# 14823                                     comedy, murder   test
# 14824                         good versus evil, violence  train
# 14825                                           anti war  train
# 14826                                             murder   test
# 14827                                     christian film   test
#
#       synopsis_source
# 0                imdb
# 1                imdb
# 2                imdb
# 3                imdb
# 4                imdb
# ...               ...
# 14823       wikipedia
# 14824       wikipedia
# 14825       wikipedia
# 14826       wikipedia
# 14827       wikipedia
#
# [14828 rows x 6 columns]

# %%
df.isnull().values.any()
# Out:
# False

# %%
df = df.drop(columns=["tags", "split", "synopsis_source"])

# %%
df
# Out:
#          imdb_id                                          title  \
# 0      tt0057603                        I tre volti della paura
# 1      tt1733125  Dungeons & Dragons: The Book of Vile Darkness
# 2      tt0033045                     The Shop Around the Corner
# 3      tt0113862                             Mr. Holland's Opus
# 4      tt0086250                                       Scarface
# ...          ...                                            ...
# 14823  tt0219952                                  Lucky Numbers
# 14824  tt1371159                                     Iron Man 2
# 14825  tt0063443                                     Play Dirty
# 14826  tt0039464                                      High Wall
# 14827  tt0235166                               Against All Hope
#
#                                            plot_synopsis
# 0      Note: this synopsis is for the orginal Italian...
# 1      Two thousand years ago, Nhagruul the Foul, a s...
# 2      Matuschek's, a gift store in Budapest, is the ...
# 3      Glenn Holland, not a morning person by anyone'...
# 4      In May 1980, a Cuban man named Tony Montana (A...
# ...                                                  ...
# 14823  In 1988 Russ Richards (John Travolta), the wea...
# 14824  In Russia, the media covers Tony Stark's discl...
# 14825  During the North African Campaign in World War...
# 14826  Steven Kenet catches his unfaithful wife in th...
# 14827  Sometime in the 1950s in Chicago a man, Cecil ...
#
# [14828 rows x 3 columns]

# %%
classifier = pipeline("text-classification",
                      model='bhadresh-savani/distilbert-base-uncased-emotion', # Maybe consider different models.
                      return_all_scores=True)
# Out:
# Downloading:   0%|          | 0.00/255M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/291 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]

# %%
nlp = spacy.load("en_core_web_sm")

# %%
# The following function returns the averages of the 6 primary emotions.
# The averages, because we must split the synopsis into sentences before training the model.
def classify_synopsis(sents, classifier):
  preds = np.array([])
  for sent in sents:
    if len(sent) > 512: # maximum accepted by the transformer!
      func = lambda l, x: [l[i:i+x] for i in range(0, len(l), x)]
      return classify_synopsis(func(sent, 512), classifier)
    prediction = classifier(str(sent))
    preds = np.append(prediction, preds)
  x = pd.DataFrame.from_records(preds)
  x = dd.from_pandas(x, npartitions=5).compute()
  r = x.groupby('label').mean()
  return r.score.to_dict()

# %%
df["emotions"] = df["plot_synopsis"].apply(lambda x: classify_synopsis(nlp(x).sents, classifier))
df.emotions
# Out:
# 0        {'anger': 0.23212224676995233, 'fear': 0.47384...
# 1        {'anger': 0.5508819421451977, 'fear': 0.064073...
# 2        {'anger': 0.21647907543305528, 'fear': 0.22596...
# 3        {'anger': 0.29966469810739604, 'fear': 0.13232...
# 4        {'anger': 0.48358979746475456, 'fear': 0.24775...
#                                ...
# 14822    {'anger': 0.3423848313457601, 'fear': 0.331624...
# 14823    {'anger': 0.4996576787671074, 'fear': 0.212360...
# 14824    {'anger': 0.5647137483324984, 'fear': 0.178041...
# 14825    {'anger': 0.34717418948809303, 'fear': 0.40262...
# 14826    {'anger': 0.2554710508723344, 'fear': 0.504246...
# Name: emotions, Length: 14827, dtype: object

# %%
df.head(10)
# Out:
#      imdb_id                                          title  \
# 0  tt0057603                        I tre volti della paura
# 1  tt1733125  Dungeons & Dragons: The Book of Vile Darkness
# 2  tt0033045                     The Shop Around the Corner
# 3  tt0113862                             Mr. Holland's Opus
# 4  tt0086250                                       Scarface
# 5  tt1315981                                   A Single Man
# 6  tt0249380                                      Baise-moi
# 7  tt0408790                                     Flightplan
# 8  tt0021079                                  Little Caesar
# 9  tt1615065                                        Savages
#
#                                        plot_synopsis  \
# 0  Note: this synopsis is for the orginal Italian...
# 1  Two thousand years ago, Nhagruul the Foul, a s...
# 2  Matuschek's, a gift store in Budapest, is the ...
# 3  Glenn Holland, not a morning person by anyone'...
# 4  In May 1980, a Cuban man named Tony Montana (A...
# 5  George Falconer (Colin Firth) approaches a car...
# 6  Baise-moi tells the story of Nadine and Manu w...
# 7  Kyle Pratt (Jodie Foster) is a propulsion engi...
# 8  Small-time Italian-American criminals Caesar E...
# 9  The movie begins with a video being shot of me...
#
#                                             emotions
# 0  {'anger': 0.23212224676995233, 'fear': 0.47384...
# 1  {'anger': 0.5508819421451977, 'fear': 0.064073...
# 2  {'anger': 0.21647907543305528, 'fear': 0.22596...
# 3  {'anger': 0.29966469810739604, 'fear': 0.13232...
# 4  {'anger': 0.48358979746475456, 'fear': 0.24775...
# 5  {'anger': 0.36766072945852585, 'fear': 0.24443...
# 6  {'anger': 0.44969198020855683, 'fear': 0.34324...
# 7  {'anger': 0.2957883257945271, 'fear': 0.501962...
# 8  {'anger': 0.6120028616195279, 'fear': 0.226918...
# 9  {'anger': 0.4545921616985204, 'fear': 0.237704...

# %%
df.iloc[7111]
# Out:
# Unnamed: 0                                                    7111
# imdb_id                                                  tt0062819
# title                                                    Commandos
# plot_synopsis    It is the middle of World War II, and in the d...
# emotions         [As a result, the elderly German soldier fires...
# Name: 7111, dtype: object

# %%
df.drop([7111], axis=0, inplace=True)

# %%
df["emotions"] = df["emotions"].apply(lambda x : dict(eval(x)))

# %%
df = pd.concat([df, df["emotions"].apply(pd.Series)], axis = 1)

# %%
df = df.drop(["emotions"],axis = 1)

# %%
df.sort_values(['anger', 'fear'], ascending=[False, False])
# Out:
#        Unnamed: 0    imdb_id                                 title  \
# 11000       11000  tt0043665         I Was a Communist for the FBI
# 13722       13722  tt0041142                          Awful Orphan
# 9919         9919  tt1190536                        Black Dynamite
# 13103       13103  tt0038671                        Kitty Kornered
# 10958       10958  tt0034524                            Blitz Wolf
# ...           ...        ...                                   ...
# 5369         5369  tt0950500                      Pen choo kab pee
# 13997       13997  tt0816556                            Lake Mungo
# 11896       11896  tt0248661                                3 A.M.
# 10634       10634  tt0382806                        Look Both Ways
# 633           633  tt1101051  The Waltons: A Decade of the Waltons
#
#                                            plot_synopsis     anger      fear  \
# 11000  Matt Cvetic (Frank Lovejoy), who works in a Pi...  0.842094  0.087138
# 13722  Charlie is showing various thing in the form o...  0.831141  0.070304
# 9919   In the 1970s, Black Dynamite, a Vietnam War ve...  0.816960  0.098479
# 13103  The neighborhood's cat owners all (literally) ...  0.814127  0.148266
# 10958  The plot is a parody of the Three Little Pigs,...  0.803907  0.099204
# ...                                                  ...       ...       ...
# 5369   The story tells of a pregnant village girl, Nu...  0.043965  0.684488
# 13997  Sixteen-year-old Alice Palmer drowns while swi...  0.042284  0.753604
# 11896  The movie starts with few students visiting a ...  0.039836  0.416681
# 10634  The film charts the stories of several people ...  0.029845  0.240438
# 633    The real-life 'John-Boy Walton' (Earl Hamner, ...  0.021421  0.067015
#
#             joy      love   sadness  surprise
# 11000  0.006485  0.000779  0.062751  0.000754
# 13722  0.082511  0.001188  0.013784  0.001072
# 9919   0.062084  0.008011  0.012441  0.002025
# 13103  0.023482  0.001388  0.011547  0.001189
# 10958  0.064039  0.001850  0.028733  0.002267
# ...         ...       ...       ...       ...
# 5369   0.090514  0.001247  0.088809  0.090977
# 13997  0.081386  0.036506  0.081508  0.004711
# 11896  0.381151  0.002937  0.094999  0.064396
# 10634  0.409241  0.100514  0.217655  0.002308
# 633    0.731056  0.102624  0.070295  0.007589
#
# [14826 rows x 10 columns]

# %%
df.to_csv("movies_emotions.csv")
